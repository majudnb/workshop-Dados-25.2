# %% [markdown]
# <a href="https://colab.research.google.com/github/majudnb/workshop-Dados-25.2/blob/main/dados_nao_tratados.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df = pd.read_csv("dados_nao_tratados.csv")
df
# Out:
#    id       nome         idade data_inscricao nota  ativo
# 0   1        Ana            25     2023-05-12  8.5    Sim
# 1   2      Bruno  vinte e três     2023/13/01  9.0   TRUE
# 2   3      Carla            30            NaN  NaN    Não
# 3   4     Daniel           NaN     2022-07-15  7.2    sim
# 4   5      Érica            27     2022-08-XX    8      e
# 5   6  Francisco            29     15/09/2022  dez  FALSE
# 6   7   Gabriela            21     2023-01-05   10   TRUE
# 7   8   Henrique            19     2023-02-30  9.5    nao
# 8   9      Ivana            11     2023-03-10  NaN    Yes
# 9  10       José             ?     2022-11-25  6.7    sim

# %%
df["data_inscricao"] = pd.to_datetime(df["data_inscricao"], errors="coerce", dayfirst=True)
print(df)
# Out:
#    id       nome         idade data_inscricao nota  ativo
# 0   1        Ana            25     2023-12-05  8.5    Sim
# 1   2      Bruno  vinte e três            NaT  9.0   TRUE
# 2   3      Carla            30            NaT  NaN    Não
# 3   4     Daniel           NaN            NaT  7.2    sim
# 4   5      Érica            27            NaT    8      e
# 5   6  Francisco            29            NaT  dez  FALSE
# 6   7   Gabriela            21     2023-05-01   10   TRUE
# 7   8   Henrique            19            NaT  9.5    nao
# 8   9      Ivana            11     2023-10-03  NaN    Yes
# 9  10       José             ?            NaT  6.7    sim

# %%
df ["idade"] = pd.to_numeric(df["idade"], errors="coerce")
df ["idade"] = df["idade"].fillna(10)
df
# Out:
#    id       nome  idade data_inscricao nota  ativo
# 0   1        Ana   25.0     2023-12-05  8.5    Sim
# 1   2      Bruno   10.0            NaT  9.0   TRUE
# 2   3      Carla   30.0            NaT  NaN    Não
# 3   4     Daniel   10.0            NaT  7.2    sim
# 4   5      Érica   27.0            NaT    8      e
# 5   6  Francisco   29.0            NaT  dez  FALSE
# 6   7   Gabriela   21.0     2023-05-01   10   TRUE
# 7   8   Henrique   19.0            NaT  9.5    nao
# 8   9      Ivana   11.0     2023-10-03  NaN    Yes
# 9  10       José   10.0            NaT  6.7    sim

# %%
df.fillna(0)
# Out:
#    id       nome  idade       data_inscricao nota  ativo
# 0   1        Ana   25.0  2023-12-05 00:00:00  8.5    Sim
# 1   2      Bruno   10.0                    0  9.0   TRUE
# 2   3      Carla   30.0                    0    0    Não
# 3   4     Daniel   10.0                    0  7.2    sim
# 4   5      Érica   27.0                    0    8      e
# 5   6  Francisco   29.0                    0  dez  FALSE
# 6   7   Gabriela   21.0  2023-05-01 00:00:00   10   TRUE
# 7   8   Henrique   19.0                    0  9.5    nao
# 8   9      Ivana   11.0  2023-10-03 00:00:00    0    Yes
# 9  10       José   10.0                    0  6.7    sim
